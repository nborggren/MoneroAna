# %%
from MoneroAna import *

# %%
num_blocks = 150
bs = [block(2850000+i) for i in range(num_blocks)]
bs_txs = [i.get_txs() for i in bs]

# %%
tot_txs = []
for i in bs_txs:
    tot_txs+=i
    
n4 = [i for i in tot_txs if i.coinbase==False and len(i.rings)==4]

# %%
len(tot_txs), len(n4)
# Out:
# (4491, 35)

# %%
txo = n4[0]
txo2 = n4[1]
print(txo.rings[0].block_no)
# Out:
# [2703435, 2746909, 2827929, 2830973, 2835426, 2842054, 2847636, 2849074, 2849330, 2849713, 2849768, 2849791, 2849822, 2849853, 2849866, 2849881]

# %%
taint_txo = taint(txo, depth = num_blocks)
taint_txo2 = taint(txo2, depth = num_blocks)
ttree = [i for i in taint_txo]
ttree2 = [i for i in taint_txo2]
#print(txs), print(coinbases)
# Out:
# loop 1
# loop 2
# 100
# loop 3
# 200
# 300
# 400
# loop 4
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# loop 5
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# loop 6
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# loop 7
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# loop 8
# 4300
# 4400
# 4500
# loop 9
# 4600
# loop 10
# loop 1
# loop 2
# loop 3
# 100
# 200
# 300
# 400
# 500
# loop 4
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# loop 5
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# loop 6
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# loop 7
# 7700
# ...

# %%
a,b,c = cotxs(ttree, ttree2)

# %%
for i in [a,b,c]:
    print(len(i))
# Out:
# 1096
# 12
# 118256

# %%
txo.rings

# %%
txo_taint_ring = taint_ring(txo.rings[0], depth=num_blocks)
txo_taint_ring1 = taint_ring(txo.rings[1], depth=num_blocks)
txo_taint_ring2 = taint_ring(txo.rings[2], depth=num_blocks)
txo_taint_ring3 = taint_ring(txo.rings[3], depth=num_blocks)

ttree = next(txo_taint_ring)
#ttree1 = next(txo_taint_ring1)
ttree2 = next(txo_taint_ring2)
#ttree3 = next(txo_taint_ring3)
# Out:
# loop 1
# loop 2
# loop 3
# loop 4
# 100
# loop 5
# 200
# 300
# loop 6
# 400
# 500
# 600
# 700
# loop 7
# 800
# 900
# loop 8
# 1000
# loop 9
# loop 10
# loop 11
# loop 1
# loop 2
# loop 3
# loop 4
# loop 5
# 100
# 200
# loop 6
# 300
# 400
# loop 7
# 500
# 600
# 700
# 800
# loop 8
# 900
# 1000
# 1100
# 1200
# 1300
# loop 9
# 1400
# 1500
# 1600
# loop 10
# 1700
# loop 11
# loop 1
# loop 2
# loop 3
# loop 4
# loop 5
# 100
# loop 6
# loop 7
# loop 8
# loop 9
# loop 10
# loop 1
# loop 2
# loop 3
# 100
# 200
# loop 4
# 300
# 400
# 500
# 600
# loop 5
# 700
# 800
# 900
# 1000
# 1100
# loop 6
# 1200
# 1300
# 1400
# loop 7
# loop 8
# loop 9
# loop 1
# loop 2
# loop 3
# loop 4
# 100
# loop 5
# loop 6
# loop 7
# 200
# loop 8
# loop 9
# loop 1
# loop 2
# loop 3
# loop 4
# loop 1
# loop 2
# loop 3
# 100
# 200
# loop 4
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# loop 5
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# ...

# %%
for m,i in enumerate(ttree):
    print('decoy', m)
    for n, j in enumerate(ttree):
        if m>=n:
            print(m, n)
            for k in cotxs(i, j):
                print(len(k))
# Out:
# decoy 0
# 0 0
# 580
# 3
# 32361
# decoy 1
# 1 0
# 0
# 0
# 123
# 1 1
# 474
# 5
# 53030
# decoy 2
# 2 0
# 0
# 0
# 0
# 2 1
# 0
# 0
# 4
# 2 2
# 129
# 0
# 4183
# decoy 3
# 3 0
# 0
# 0
# 30
# 3 1
# 0
# 0
# 38
# 3 2
# 0
# 0
# 678
# 3 3
# 541
# 7
# 47909
# decoy 4
# 4 0
# 0
# 0
# 4
# 4 1
# 0
# 0
# 10
# 4 2
# 0
# 0
# 61
# 4 3
# 0
# 0
# 284
# 4 4
# 171
# 3
# 8610
# decoy 5
# 5 0
# 0
# 0
# 0
# 5 1
# 0
# 0
# 0
# 5 2
# 0
# 0
# 0
# 5 3
# 0
# 0
# 1
# 5 4
# 0
# 0
# 2
# 5 5
# 13
# 0
# 322
# decoy 6
# 6 0
# 0
# 0
# 197
# 6 1
# 0
# 0
# 257
# 6 2
# 0
# 0
# 1335
# 6 3
# 0
# 0
# 4370
# 6 4
# 0
# 0
# 3313
# 6 5
# 0
# 0
# 614
# 6 6
# 1720
# 17
# 474076
# decoy 7
# 7 0
# 0
# 0
# 3
# 7 1
# 0
# 0
# 3
# 7 2
# 0
# 0
# 10
# 7 3
# 0
# 0
# 39
# 7 4
# 0
# 0
# 33
# 7 5
# 0
# 0
# 5
# 7 6
# 0
# 0
# 710
# 7 7
# 176
# 1
# 6174
# decoy 8
# 8 0
# 0
# 0
# 246
# 8 1
# 0
# 0
# 474
# 8 2
# 0
# 0
# 1819
# 8 3
# 0
# 0
# 6722
# 8 4
# 0
# 0
# 4795
# 8 5
# 0
# 0
# 888
# 8 6

# %%
for m,i in enumerate(ttree):
    print(m)
    for n, j in enumerate(ttree2):
        if m>=n:
            print(m, n)
            for k in cotxs(i, j):
                print(len(k))

# %%
ttree[1]

# %%
n = [i for i in tot_txs if i.coinbase==False and len(i.rings)>25]

# %%
n

# %%
n0_taint_rings = [taint_ring(i, depth=num_blocks) for i in n[0].rings[:2]]

# %%
n1 = [[j for j in i] for i in n0_taint_rings]
# Out:
# loop 1
# loop 2
# loop 3
# 100
# 200
# 300
# loop 4
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# loop 5
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# loop 6
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# ...
